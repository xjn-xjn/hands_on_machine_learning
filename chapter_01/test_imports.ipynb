# %% [markdown]
# # Test imports to be used in book

# %%
import tensorflow as tf
import sklearn as sk
import keras

# %%
print(tf.__version__)
# Out:
# 2.6.0

# %%
print(sk.__version__)
# Out:
# 1.0

# %%
print(keras.__version__)
# Out:
# 2.6.0

# %% [markdown]
# <hr>

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 10, 0.001)
y = np.cos(x)

# %%
# %matplotlib inline

# %%
plt.plot(x, y)

# %% [markdown]
# <hr>
